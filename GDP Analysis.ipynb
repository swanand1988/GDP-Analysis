# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_gdp = pd.read_csv('Gross Domestic Product (GDP) at Current Price.csv')
df_gdp.head()
# Out:
#                     Items Description Duration  Andhra Pradesh  \
# 0       (% Growth over previous year)  2013-14           12.85
# 1       (% Growth over previous year)  2014-15           13.40
# 2       (% Growth over previous year)  2015-16           15.85
# 3       (% Growth over previous year)  2016-17           14.65
# 4  GSDP - CURRENT PRICES (` in Crore)  2011-12       379402.00
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0              16.38      13.31      12.30         16.44     -5.77      11.47
# 1              14.79      11.45      17.92         13.69     13.12      10.82
# 2              12.07      13.19      10.59         10.98     10.75      11.09
# 3                NaN        NaN        NaN         11.26       NaN        NaN
# 4           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
#
#      Haryana  ...  Telangana   Tripura  Uttar Pradesh  Uttarakhand  \
# ...

# %%
df_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Items Description          10 non-null     object
#  1   Duration                   10 non-null     object
#  2   Andhra Pradesh             10 non-null     float64
#  3   Arunachal Pradesh          8 non-null      float64
#  4   Assam                      8 non-null      float64
#  5   Bihar                      8 non-null      float64
#  6   Chhattisgarh               10 non-null     float64
#  7   Goa                        8 non-null      float64
#  8   Gujarat                    8 non-null      float64
#  9   Haryana                    10 non-null     float64
#  10  Himachal Pradesh           6 non-null      float64
#  11  Jammu & Kashmir            8 non-null      float64
#  12  Jharkhand                  8 non-null      float64
# ...

# %%
df_gdp.describe()
# Out:
#        Andhra Pradesh  Arunachal Pradesh          Assam          Bihar  \
# count       10.000000           8.000000       8.000000       8.000000
# mean    309084.375000        9225.030000  112519.243750  204259.601250
# std     281194.758635        7982.092133   96316.252356  176631.136526
# min         12.850000          12.070000      11.450000      10.590000
# 25%         14.950000          15.982500      13.280000      16.515000
# 50%     395403.000000       11805.000000  150019.500000  264756.000000
# 75%     510919.000000       15141.750000  182833.250000  331305.750000
# max     699307.000000       18784.000000  224234.000000  413503.000000
#
#         Chhattisgarh           Goa        Gujarat        Haryana  \
# count      10.000000      8.000000       8.000000      10.000000
# mean   132822.537000  25257.637500  504637.547500  251532.336000
# std    120278.343923  21081.645122  432366.224823  226868.645298
# min        10.980000     -5.770000      10.820000       9.180000
# ...

# %%
df_gdp.isnull().sum()
# Out:
# Items Description             0
# Duration                      0
# Andhra Pradesh                0
# Arunachal Pradesh             2
# Assam                         2
# Bihar                         2
# Chhattisgarh                  0
# Goa                           2
# Gujarat                       2
# Haryana                       0
# Himachal Pradesh              4
# Jammu & Kashmir               2
# Jharkhand                     2
# Karnataka                     2
# Kerala                        2
# Madhya Pradesh                0
# Maharashtra                   4
# Manipur                       4
# Meghalaya                     0
# Mizoram                       4
# Nagaland                      4
# Odisha                        0
# Punjab                        4
# Rajasthan                     4
# Sikkim                        2
# Tamil Nadu                    0
# Telangana                     0
# Tripura                       4
# Uttar Pradesh                 2
# ...

# %%
pd.pivot_table(df_gdp,index=['Items Description','Duration'])
# Out:
#                                              All_India GDP  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14           12.97
#                                    2014-15           10.65
#                                    2015-16            9.99
#                                    2016-17           11.52
# GSDP - CURRENT PRICES (` in Crore) 2011-12      8736039.00
#                                    2012-13      9946636.00
#                                    2013-14     11236635.00
#                                    2014-15     12433749.00
#                                    2015-16     13675331.00
#                                    2016-17     15251028.00
#
#                                              Andaman & Nicobar Islands  \
# Items Description                  Duration
# (% Growth over previous year)      2013-14                       16.68
#                                    2014-15                       10.89
# ...

# %%
df_gdp=df_gdp.drop(df_gdp.index[[3,9]])

# %%
df_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 0 to 8
# Data columns (total 36 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Items Description          8 non-null      object
#  1   Duration                   8 non-null      object
#  2   Andhra Pradesh             8 non-null      float64
#  3   Arunachal Pradesh          8 non-null      float64
#  4   Assam                      8 non-null      float64
#  5   Bihar                      8 non-null      float64
#  6   Chhattisgarh               8 non-null      float64
#  7   Goa                        8 non-null      float64
#  8   Gujarat                    8 non-null      float64
#  9   Haryana                    8 non-null      float64
#  10  Himachal Pradesh           6 non-null      float64
#  11  Jammu & Kashmir            8 non-null      float64
#  12  Jharkhand                  8 non-null      float64
# ...

# %%
df_gdp
# Out:
#                     Items Description Duration  Andhra Pradesh  \
# 0       (% Growth over previous year)  2013-14           12.85
# 1       (% Growth over previous year)  2014-15           13.40
# 2       (% Growth over previous year)  2015-16           15.85
# 4  GSDP - CURRENT PRICES (` in Crore)  2011-12       379402.00
# 5  GSDP - CURRENT PRICES (` in Crore)  2012-13       411404.00
# 6  GSDP - CURRENT PRICES (` in Crore)  2013-14       464272.00
# 7  GSDP - CURRENT PRICES (` in Crore)  2014-15       526468.00
# 8  GSDP - CURRENT PRICES (` in Crore)  2015-16       609934.00
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0              16.38      13.31      12.30         16.44     -5.77      11.47
# 1              14.79      11.45      17.92         13.69     13.12      10.82
# 2              12.07      13.19      10.59         10.98     10.75      11.09
# 4           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# ...

# %%
column_attribute=list(df_gdp.columns)

# %%
del(column_attribute[0])
del(column_attribute[0])
states=column_attribute
states
# Out:
# ['Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal1',
#  'Andaman & Nicobar Islands',
#  'Chandigarh',
#  'Delhi',
#  'Puducherry',
#  'All_India GDP']

# %%
state_mean={}
for column in df_gdp:
    if column in states:
        mean=df_gdp[df_gdp["Items Description"]=="(% Growth over previous year)"][column].mean()
        state_mean[column]=mean
state_mean["Items Description"]="Average growth rate"
df_gdp=df_gdp.append(state_mean,ignore_index=True)

# %%
df_gdp
# Out:
#                     Items Description Duration  Andhra Pradesh  \
# 0       (% Growth over previous year)  2013-14       12.850000
# 1       (% Growth over previous year)  2014-15       13.400000
# 2       (% Growth over previous year)  2015-16       15.850000
# 3  GSDP - CURRENT PRICES (` in Crore)  2011-12   379402.000000
# 4  GSDP - CURRENT PRICES (` in Crore)  2012-13   411404.000000
# 5  GSDP - CURRENT PRICES (` in Crore)  2013-14   464272.000000
# 6  GSDP - CURRENT PRICES (` in Crore)  2014-15   526468.000000
# 7  GSDP - CURRENT PRICES (` in Crore)  2015-16   609934.000000
# 8                 Average growth rate      NaN       14.033333
#
#    Arunachal Pradesh      Assam          Bihar   Chhattisgarh           Goa  \
# 0          16.380000      13.31      12.300000      16.440000     -5.770000
# 1          14.790000      11.45      17.920000      13.690000     13.120000
# 2          12.070000      13.19      10.590000      10.980000     10.750000
# ...

# %%
df_gdp=df_gdp.iloc[[2,7,8],:]
df_gdp
# Out:
#                     Items Description Duration  Andhra Pradesh  \
# 2       (% Growth over previous year)  2015-16       15.850000
# 7  GSDP - CURRENT PRICES (` in Crore)  2015-16   609934.000000
# 8                 Average growth rate      NaN       14.033333
#
#    Arunachal Pradesh      Assam          Bihar   Chhattisgarh           Goa  \
# 2          12.070000      13.19      10.590000      10.980000     10.750000
# 7       18784.000000  224234.00  413503.000000  260776.000000  45002.000000
# 8          14.413333      12.65      13.603333      13.703333      6.033333
#
#          Gujarat        Haryana  ...      Telangana  Tripura  Uttar Pradesh  \
# 2      11.090000      10.910000  ...      12.610000      NaN          10.58
# 7  994316.000000  485184.000000  ...  575631.000000      NaN     1153795.00
# 8      11.126667      11.846667  ...      12.763333    17.03          11.94
#
#      Uttarakhand  West Bengal1  Andaman & Nicobar Islands  Chandigarh  \
# ...

# %%
gdp=df_gdp.T

# %%
gdp
# Out:
#                                                        2  \
# Items Description          (% Growth over previous year)
# Duration                                         2015-16
# Andhra Pradesh                                     15.85
# Arunachal Pradesh                                  12.07
# Assam                                              13.19
# Bihar                                              10.59
# Chhattisgarh                                       10.98
# Goa                                                10.75
# Gujarat                                            11.09
# Haryana                                            10.91
# Himachal Pradesh                                     NaN
# Jammu & Kashmir                                    17.91
# Jharkhand                                          11.44
# Karnataka                                          11.42
# Kerala                                             11.85
# ...

# %%
gdp.columns=gdp.iloc[0]
gdp=gdp[1:]
gdp=gdp[1:]
gdp
# Out:
# Items Description         (% Growth over previous year)  \
# Andhra Pradesh                                    15.85
# Arunachal Pradesh                                 12.07
# Assam                                             13.19
# Bihar                                             10.59
# Chhattisgarh                                      10.98
# Goa                                               10.75
# Gujarat                                           11.09
# Haryana                                           10.91
# Himachal Pradesh                                    NaN
# Jammu & Kashmir                                   17.91
# Jharkhand                                         11.44
# Karnataka                                         11.42
# Kerala                                            11.85
# Madhya Pradesh                                    12.86
# Maharashtra                                         NaN
# Manipur                                             NaN
# ...

# %%
gdp["Average growth rate"].sort_values().plot.bar()

# %% [markdown]
# Insightes:
# 1. Rate of GDP Growth in North East States like mizoram, Tripura and Nagaland is high.
# 2. States like goa, Meghalaya, Odisha, sikkim and J&K is struggling with GDP growth
# 3. All India GDP is not so relatively low
# 4. GDP growth of bihar, chattisgarh, A&N, Andhra Pradesh, Karnataka and Arunachal Pradesh are relatively high
# 5. For all other states, GDP growth is medium

# %%
gdp["GSDP - CURRENT PRICES (` in Crore)"].drop("All_India GDP",axis=0).sort_values().plot.bar()

# %% [markdown]
# Insights:
# 1. As GDP of Tamilnadu, Uttar pradesh and karnataka is vary high.
# 2. The GDP of skkim, Arunachal Pradesh and Puducherry is very low.
# 3. Some of the states having medium GDP

# %%
states
# Out:
# ['Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal1',
#  'Andaman & Nicobar Islands',
#  'Chandigarh',
#  'Delhi',
#  'Puducherry',
#  'All_India GDP']

# %%
states=['Andhra_Pradesh',
 'Arunachal_Pradesh',
 'Assam',
 'Bihar',
 'Chhattisgarh',
 'Goa',
 'Gujarat',
 'Haryana',
 'Himachal_Pradesh',
 'Jammu & Kashmir',
 'Jharkhand',
 'Karnataka',
 'Kerala',
 'Madhya_Pradesh',
 'Maharashtra',
 'Manipur',
 'Meghalaya',
 'Mizoram',
 'Nagaland',
 'Odisha',
 'Punjab',
 'Rajasthan',
 'Sikkim',
 'Tamil Nadu',
 'Telangana',
 'Tripura',
 'Uttar_Pradesh',
 'Uttarakhand',
 'West Bengal']

# %%
import os

# %%
gsva=pd.DataFrame()

# %%
path=('C:\\Users\\Admin\\Desktop\\DS with Decodr\\Case Studies\\Case Study 3_ GDP Analysis with Niti Ayog-20210407T045624Z-001\\Case Study 3_ GDP Analysis with Niti Ayog\\Datasets\\GSVA\\')

# %%
lstofpath=os.listdir(path)

# %%
len(lstofpath)
# Out:
# 29

# %%
len(states)
# Out:
# 29

# %%
for filename in lstofpath:
    for statename in states:
        if statename in filename:
            filepath=path+filename
            data=pd.read_csv(filepath,encoding='ISO-8859-1')
            data=data[['Item','2014-15']]
            data=data.T
            data.columns=data.iloc[0]
            data=data[1:]
            data["state"]=statename
            gsva=pd.concat([data,gsva])

# %%
gsva.set_index("state",inplace=True)

# %%
gsva
# Out:
#                   Agriculture, forestry and fishing        Crops    Livestock  \
# state
# Uttar_Pradesh                              25097754     16215212      7096876
# Uttarakhand                             1.60142e+06       866146       391188
# Tripura                                      799825       397591        88176
# Telangana                                   7591501      4162493      2951299
# Sikkim                                       137447       114976        17338
# Rajasthan                                  15044394      7673441      5356257
# Punjab                                      9285716      5690972      2638842
# Odisha                                      6422978      4382636       788243
# Nagaland                                     607897       375825       123800
# Meghalaya                                    366521       223330        72442
# Manipur                                      383140       226583        75483
# ...

# %%
gsva.columns
# Out:
# Index(['Agriculture, forestry and fishing', 'Crops', 'Livestock',
#        'Forestry and logging', 'Fishing and aquaculture',
#        'Mining and quarrying', 'Primary', 'Manufacturing',
#        'Electricity, gas, water supply & other utility services',
#        'Construction', 'Secondary', 'Trade, repair, hotels and restaurants',
#        'Trade & repair services', 'Hotels & restaurants',
#        'Transport, storage, communication & services related to broadcasting',
#        'Railways', 'Road transport', 'Water transport', 'Air transport',
#        'Services incidental to transport', 'Storage',
#        'Communication & services related to broadcasting',
#        'Financial services',
#        'Real estate, ownership of dwelling & professional services',
#        'Public administration', 'Other services', 'Tertiary',
#        'TOTAL GSVA at basic prices', 'Taxes on Products',
#        'Subsidies on products', 'Gross State Domestic Product',
# ...

# %%
gsva['Per Capita GSDP (Rs.)'].sort_values().plot.bar()

# %% [markdown]
# Insights:
# 1. Goa, Sikkim, Haryana, kerala and uttarkhand is having highest GDP per capita.
# 2. Bihar, uttar pradesh, manipur, Jharkhand, madhya pradesh is having lowest GDP per capita.
# 3. All other states is having medium GDP per capita.

# %%
gsva['Per Capita GSDP (Rs.)'].sort_values()['Goa']/gsva['Per Capita GSDP (Rs.)'].sort_values()['Bihar']
# Out:
# 8.004741709371503

# %%
gsva['primary_gdp_percent']=0
gsva['secondary_gdp_percent']=0
gsva['tertiary_gdp_percent']=0

# %%
gsva
# Out:
#                   Agriculture, forestry and fishing        Crops    Livestock  \
# state
# Uttar_Pradesh                              25097754     16215212      7096876
# Uttarakhand                             1.60142e+06       866146       391188
# Tripura                                      799825       397591        88176
# Telangana                                   7591501      4162493      2951299
# Sikkim                                       137447       114976        17338
# Rajasthan                                  15044394      7673441      5356257
# Punjab                                      9285716      5690972      2638842
# Odisha                                      6422978      4382636       788243
# Nagaland                                     607897       375825       123800
# Meghalaya                                    366521       223330        72442
# Manipur                                      383140       226583        75483
# ...

# %%
for i in range(len(gsva)):
    gsva.iloc[i,37]=gsva.iloc[i,6]/gsva.iloc[i,30]
    gsva.iloc[i,38]=gsva.iloc[i,10]/gsva.iloc[i,30]
    gsva.iloc[i,39]=gsva.iloc[i,26]/gsva.iloc[i,30]

# %%
gsva.sort_values('Per Capita GSDP (Rs.)')[['primary_gdp_percent','secondary_gdp_percent','tertiary_gdp_percent']].plot.bar()

# %%
gsva.sort_values('Per Capita GSDP (Rs.)')[['primary_gdp_percent','secondary_gdp_percent','tertiary_gdp_percent']].plot(kind='bar',stacked=True)

# %%
gsva.sort_values('Per Capita GSDP (Rs.)')["Population ('00)"].plot(kind='bar')

# %% [markdown]
# Insights:
# 1. For states which has low per capita income, has significant dependence on primary source whereas states which have high per capta income relies more on secondary and tertiary
# 2. UP has high GDP but due to its population, has low per capita income

# %%
per_capita=gsva['Per Capita GSDP (Rs.)'].sort_values()

# %%
per_capita.quantile([0.2,0.5,0.8,1.0])
# Out:
# 0.2    62629.8
# 0.5      97292
# 0.8     152942
# 1.0     271793
# Name: Per Capita GSDP (Rs.), dtype: object

# %%
per_capita.sort_values(ascending=False)
# Out:
# state
# Goa                  271793
# Sikkim               240274
# Haryana              164077
# Kerala               154778
# Uttarakhand          153076
# Maharashtra          152853
# Karnataka            145141
# Gujarat              141263
# Telangana            139035
# Punjab               126606
# Arunachal_Pradesh    112718
# Andhra_Pradesh       104977
# Nagaland              89607
# Chhattisgarh          86860
# Rajasthan             84837
# Tripura               77358
# Meghalaya             76228
# Odisha                73979
# Madhya_Pradesh        62989
# Jharkhand             62091
# Assam                 60621
# Manipur               58442
# Uttar_Pradesh         49450
# Bihar                 33954
# Name: Per Capita GSDP (Rs.), dtype: object

# %%
C_1=['Goa','Sikkim','Haryana','Kerala','Uttarakhand' ]
C_2=['Maharashtra','Karnataka','Gujarat','Telangana','Punjab','Arunachal_Pradesh','Andhra_Pradesh' ]
C_3=['Nagaland','Chhattisgarh','Rajasthan','Tripura','Meghalaya','Odisha','Madhya_Pradesh']
C_4=['Jharkhand','Assam','Manipur','Uttar_Pradesh','Bihar']
C_columns = ['Agriculture, forestry and fishing', 'Mining and quarrying', 'Manufacturing',
                      'Electricity, gas, water supply & other utility services', 'Construction',
                      'Trade, repair, hotels and restaurants',
                      'Transport, storage, communication & services related to broadcasting', 
                      'Financial services', 'Real estate, ownership of dwelling & professional services',
                      'Public administration', 'Other services', 'Taxes on Products', 'Subsidies on products']

# %% [markdown]
# # Category 1 states(C_1)

# %%
agg=gsva.loc[C_1,C_columns].sum()
agg
# Out:
# Agriculture, forestry and fishing                                       15993232.0
# Mining and quarrying                                                      833510.0
# Manufacturing                                                           19625045.0
# Electricity, gas, water supply & other utility services                  2434878.0
# Construction                                                            12607184.0
# Trade, repair, hotels and restaurants                                   15738265.0
# Transport, storage, communication & services related to broadcasting     7885253.0
# Financial services                                                       4321519.0
# Real estate, ownership of dwelling & professional services              15571552.0
# Public administration                                                    4150701.0
# Other services                                                           9042352.0
# ...

# %%
agg_GSDP=gsva.loc[C_1,'Gross State Domestic Product'].sum()
agg_GSDP
# Out:
# 118129206.0

# %%
round(100*agg/agg_GSDP).sort_values(ascending=False)
# Out:
# Manufacturing                                                           17.0
# Agriculture, forestry and fishing                                       14.0
# Real estate, ownership of dwelling & professional services              13.0
# Trade, repair, hotels and restaurants                                   13.0
# Construction                                                            11.0
# Taxes on Products                                                       10.0
# Other services                                                           8.0
# Transport, storage, communication & services related to broadcasting     7.0
# Public administration                                                    4.0
# Financial services                                                       4.0
# Subsidies on products                                                    2.0
# Electricity, gas, water supply & other utility services                  2.0
# ...

# %%
round(100*agg/agg_GSDP).sort_values(ascending=False)[0:6].plot.bar()

# %% [markdown]
# Insights:
# In this category 5 states all these states having good business in manufacturing and agriculture sector.
# 1. For these states business should be improve in constuction and trade and hospitality sectors.
# 2. Also need the improvement in taxes on product sector also.

# %% [markdown]
# # Category 2 (C_2)

# %%
agg2=gsva.loc[C_2,C_columns].sum()
agg2
# Out:
# Agriculture, forestry and fishing                                       73847796.00
# Mining and quarrying                                                    11314176.00
# Manufacturing                                                           86544113.00
# Electricity, gas, water supply & other utility services                 12063580.00
# Construction                                                            30950744.00
# Trade, repair, hotels and restaurants                                   50217818.00
# Transport, storage, communication & services related to broadcasting    30019545.00
# Financial services                                                      31851456.00
# Real estate, ownership of dwelling & professional services              77739398.00
# Public administration                                                   16234529.00
# Other services                                                          31133337.00
# ...

# %%
agg2.GSDP=gsva.loc[C_2,'Gross State Domestic Product'].sum()
agg2.GSDP
# Out:
# 503135513.0

# %%
round(100*agg2/agg2.GSDP).sort_values(ascending=False)
# Out:
# Manufacturing                                                           17.0
# Real estate, ownership of dwelling & professional services              15.0
# Agriculture, forestry and fishing                                       15.0
# Taxes on Products                                                       12.0
# Trade, repair, hotels and restaurants                                   10.0
# Other services                                                           6.0
# Financial services                                                       6.0
# Transport, storage, communication & services related to broadcasting     6.0
# Construction                                                             6.0
# Public administration                                                    3.0
# Subsidies on products                                                    2.0
# Electricity, gas, water supply & other utility services                  2.0
# ...

# %%
round(100*agg2/agg2.GSDP).sort_values(ascending=False).plot.bar()

# %% [markdown]
# Insights:
# Category 2 is having 7 states all these are good in manufacturing sector.
# 1. All these states having good in agriculture and real estate sectors but need to improve more.
# 2. Also need to improve in taxes on products and hospitality sectors.
# 3. All other sectors need to improve more.

# %% [markdown]
# # Category 3 (C_3)

# %%
agg3=gsva.loc[C_3,C_columns].sum()
print(agg3)

agg3_GSDP=gsva.loc[C_3,'Gross State Domestic Product'].sum()
print('agg3_GSDP is',agg3_GSDP)
# Out:
# Agriculture, forestry and fishing                                       43426109.0
# Mining and quarrying                                                    10961256.0
# Manufacturing                                                           21726419.0
# Electricity, gas, water supply & other utility services                  4597585.0
# Construction                                                            15312955.0
# Trade, repair, hotels and restaurants                                   18255109.0
# Transport, storage, communication & services related to broadcasting     9967715.0
# Financial services                                                       5830989.0
# Real estate, ownership of dwelling & professional services              14423764.0
# Public administration                                                    8017338.0
# Other services                                                          11161611.0
# ...

# %%
round(100*agg3/agg3_GSDP).sort_values(ascending=False)
# Out:
# Agriculture, forestry and fishing                                       25.0
# Manufacturing                                                           13.0
# Trade, repair, hotels and restaurants                                   11.0
# Taxes on Products                                                        9.0
# Construction                                                             9.0
# Real estate, ownership of dwelling & professional services               8.0
# Other services                                                           6.0
# Transport, storage, communication & services related to broadcasting     6.0
# Mining and quarrying                                                     6.0
# Public administration                                                    5.0
# Subsidies on products                                                    4.0
# Financial services                                                       3.0
# ...

# %%
round(100*agg3/agg3_GSDP).sort_values(ascending=False).plot.bar()

# %% [markdown]
# Insights:
# 1. 7 states in this category and all these states are good in agriculture sector only.
# 2. The manufacturing and hospitality sectors are ggod but need to improve.
# 3. All other sector need to focous.

# %% [markdown]
# # Category 4 (C_4)

# %%
agg4=gsva.loc[C_4,C_columns].sum()
print(agg3)

agg4_GSDP=gsva.loc[C_4,'Gross State Domestic Product'].sum()
print('agg4_GSDP is',agg4_GSDP)
# Out:
# Agriculture, forestry and fishing                                       43426109.0
# Mining and quarrying                                                    10961256.0
# Manufacturing                                                           21726419.0
# Electricity, gas, water supply & other utility services                  4597585.0
# Construction                                                            15312955.0
# Trade, repair, hotels and restaurants                                   18255109.0
# Transport, storage, communication & services related to broadcasting     9967715.0
# Financial services                                                       5830989.0
# Real estate, ownership of dwelling & professional services              14423764.0
# Public administration                                                    8017338.0
# Other services                                                          11161611.0
# ...

# %%
round(100*agg4/agg4_GSDP).sort_values(ascending=False)
# Out:
# Agriculture, forestry and fishing                                       22.0
# Real estate, ownership of dwelling & professional services              12.0
# Trade, repair, hotels and restaurants                                   12.0
# Manufacturing                                                           11.0
# Taxes on Products                                                       10.0
# Construction                                                            10.0
# Other services                                                           7.0
# Transport, storage, communication & services related to broadcasting     7.0
# Public administration                                                    6.0
# Subsidies on products                                                    3.0
# Financial services                                                       3.0
# Electricity, gas, water supply & other utility services                  2.0
# ...

# %%
round(100*agg4/agg4_GSDP).sort_values(ascending=False).plot.bar()

# %% [markdown]
# Insights:
# 1. 5 states are in this category and all these are good in agriculture sector.
# 2. Manufacturing, trade, real estate sectors are good but need to improve.
# 3. All other sectors need to focous more.

# %% [markdown]
# # END
